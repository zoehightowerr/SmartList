# %% [markdown]
# # SmartList Pipeline Notebook
# This notebook walks through the full data pipeline for the SmartList playlist generator, from data loading to playlist creation.

# %%
import os
import sys
# Add project root to sys.path
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.insert(0, project_root)

# Imports
import pandas as pd
import random
import hashlib
from scripts.data_extraction import load_data
from scripts.clustering import (
    k_means_clustering,
    add_popularity_scores,
    generate_cluster_playlists,
    summarize_clusters,
    calculate_silhouette_score,
    get_top_artists_per_cluster,
    get_top_songs_per_cluster
)

# %% [markdown]
# ## 1. Load Data

# %%
# Set data path and load
data_path = '/Users/zoehightower/Desktop/SmartList/data/Raw Data'
history_data, song_data = load_data(data_path)

# Inspect
print(f"History data shape: {history_data.shape}")
print(f"Song data shape: {song_data.shape}")
# Out:
# History data shape: (85547, 8)
# Song data shape: (8876, 8)

# %%
history_data.tail()
# Out:
#         dow_sin  dow_cos  time_sin  time_cos                   track  \
# 85542 -0.781831  0.62349 -0.446198  0.894934             tolerate it
# 85543 -0.781831  0.62349 -0.446198  0.894934              No Friends
# 85544 -0.781831  0.62349 -0.442289  0.896873      Are You Satisfied?
# 85545 -0.781831  0.62349 -0.442289  0.896873  This Feeling Will Pass
# 85546 -0.781831  0.62349 -0.442289  0.896873                   Tired
#
#              artist              album                                   uri
# 85542  Taylor Swift           evermore  spotify:track:0PurA4JVJ8YQgSVopY8fn6
# 85543       CADMIUM         No Friends  spotify:track:4U7G8dgUodMEVSv96QRcDb
# 85544        MARINA  The Family Jewels  spotify:track:6lKRMylSZMtA7EqPl0pcdI
# 85545     Take Care             Reject  spotify:track:6pLGnO6JyJdtp4WlX5ixkI
# 85546   beabadoobee         Patched Up  spotify:track:6F5mZpEEjhsAW8UEqbIpz1

# %%
song_data.head()
# Out:
#    count             track                 artist             album  \
# 0    640     Cool About It              boygenius        the record
# 1    470           The Cue  Sarah and the Sundays   Like A Damn Dog
# 2    325      Words I Used    The Backseat Lovers  Waiting to Spill
# 3    317  Good Luck, Babe!          Chappell Roan  Good Luck, Babe!
# 4    311  Growing Sideways             Noah Kahan      Stick Season
#
#    min_listened  shuffle  skip                                   uri
# 0   1398.722900      293   169  spotify:track:5PJH1U5Iie893v48Fl9yaC
# 1   1543.485700      328   125  spotify:track:3O3cErOLH8t8hiqlXADzJN
# 2   1217.751083      230   107  spotify:track:34nYWTBYOKfTFYKIhVrqdT
# 3    890.411933      200    78  spotify:track:0WbMK4wrZ1wFSty9F7FCgu
# 4   1069.759783      189    53  spotify:track:1JcIXOir94YUYBt2cXTzn2

# %% [markdown]
# ## 2. Clustering and Silhouette Score

# %%
# Perform K-Means clustering
clustered_df = k_means_clustering(history_data, n_clusters=50)

# Calculate silhouette score
sil_score = calculate_silhouette_score(clustered_df)
print(f"Silhouette Score: {sil_score:.3f}")

# Show sample of clustered data
clustered_df.tail()
# Out:
# Silhouette Score: 0.532
#         dow_sin  dow_cos  time_sin  time_cos                   track  \
# 85542 -0.781831  0.62349 -0.446198  0.894934             tolerate it
# 85543 -0.781831  0.62349 -0.446198  0.894934              No Friends
# 85544 -0.781831  0.62349 -0.442289  0.896873      Are You Satisfied?
# 85545 -0.781831  0.62349 -0.442289  0.896873  This Feeling Will Pass
# 85546 -0.781831  0.62349 -0.442289  0.896873                   Tired
#
#              artist              album                                   uri  \
# 85542  Taylor Swift           evermore  spotify:track:0PurA4JVJ8YQgSVopY8fn6
# 85543       CADMIUM         No Friends  spotify:track:4U7G8dgUodMEVSv96QRcDb
# 85544        MARINA  The Family Jewels  spotify:track:6lKRMylSZMtA7EqPl0pcdI
# 85545     Take Care             Reject  spotify:track:6pLGnO6JyJdtp4WlX5ixkI
# 85546   beabadoobee         Patched Up  spotify:track:6F5mZpEEjhsAW8UEqbIpz1
#
#        cluster
# 85542        8
# 85543        8
# 85544        8
# 85545        8
# 85546        8

# %% [markdown]
# ## 3. Summarize Clusters

# %%
# Generate cluster summaries
summaries = summarize_clusters(clustered_df)
print("Cluster summaries:")
summaries.head()
# Out:
# Cluster summaries:
#    cluster      day   time_range  count                     name
# 0        0   Friday  12:18–15:29   2052    Friday lazy afternoon
# 1        1  Tuesday  17:27–20:10   1911    Tuesday moody evening
# 2        2   Friday  00:00–23:58   1553  Friday familiar all day
# 3        3   Monday  06:42–11:21   1410    Monday mellow morning
# 4        4   Sunday  16:45–19:19   2192      Sunday hazy evening

# %% [markdown]
# ## 4. Process Time Labels & Add Gradients

# %%
# Define helper functions
def process_time_label(time_range):
    h, m = time_range.split('–')[0].split(':')
    start_minutes = int(h) * 60 + int(m)
    if   300  <= start_minutes <  720: return 'morning'
    elif 720  <= start_minutes < 1020: return 'afternoon'
    elif 1020 <= start_minutes < 1320: return 'evening'
    else:                              return 'late_night'

# Apply labels and compute start time in minutes
summaries['time_label']    = summaries['time_range'].apply(process_time_label)
summaries['start_minutes'] = summaries['time_range'].apply(
    lambda tr: int(tr.split('–')[0].split(':')[0]) * 60 
             + int(tr.split('–')[0].split(':')[1])
)

# If you don't need any color info, stop here:
print("Summaries without gradients:")
summaries.head()
# Out:
# Summaries without gradients:
#    cluster      day   time_range  count                     name  time_label  \
# 0        0   Friday  12:18–15:29   2052    Friday lazy afternoon   afternoon
# 1        1  Tuesday  17:27–20:10   1911    Tuesday moody evening     evening
# 2        2   Friday  00:00–23:58   1553  Friday familiar all day  late_night
# 3        3   Monday  06:42–11:21   1410    Monday mellow morning     morning
# 4        4   Sunday  16:45–19:19   2192      Sunday hazy evening   afternoon
#
#    start_minutes
# 0            738
# 1           1047
# 2              0
# 3            402
# 4           1005

# %% [markdown]
# ## 5. Group Clusters by Day

# %%
days = ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']
clusters_by_day = {
    day: sorted(
        [r for r in summaries.to_dict(orient='records') if r['day'] == day],
        key=lambda r: r['start_minutes']
    ) for day in days
}

# Display as a table for Monday
mon_df = pd.DataFrame(clusters_by_day['Monday'])
print("Clusters for Monday:")
display(mon_df.head())
# Out:
# Clusters for Monday:
#    cluster     day   time_range  count                        name  \
# 0       21  Monday  00:00–23:58   1794     Monday familiar all day
# 1       35  Monday  01:42–06:41    488  Monday electric late night
# 2        3  Monday  06:42–11:21   1410       Monday mellow morning
# 3       34  Monday  11:21–14:00   2188  Monday wandering afternoon
# 4       20  Monday  14:02–16:39   2025     Monday bright afternoon
#
#    time_label  start_minutes
# 0  late_night              0
# 1  late_night            102
# 2     morning            402
# 3     morning            681
# 4   afternoon            842

# %% [markdown]
# ## 6. Top Artists & Songs

# %%
# Add popularity scores and get top lists
song_data_scored = add_popularity_scores(song_data)
top_artists = get_top_artists_per_cluster(clustered_df)
top_songs   = get_top_songs_per_cluster(clustered_df, top_n=50)

# Display top lists for cluster 0 as tables
print("Top artists for cluster 0:")
display(top_artists[0].head())

print("Top songs for cluster 0:")
display(top_songs[0].head())
# Out:
# Top artists for cluster 0:
#               artist  listen_count
# 0      Gracie Abrams           116
# 1       Taylor Swift           113
# 2        The Strokes            80
# 3  Sabrina Carpenter            79
# 4         Noah Kahan            72
# Top songs for cluster 0:
#                              track             artist  \
# 51                          Amoeba             Clairo
# 396              I Told You Things      Gracie Abrams
# 137                     Busy Woman  Sabrina Carpenter
# 329  Guess featuring Billie Eilish         Charli xcx
# 312        Girl You Know It's True      Milli Vanilli
#
#                                       uri                          album  \
# 51   spotify:track:0HAqq2GcQKyi3s87GuN7jU                          Sling
# 396  spotify:track:5V6mK1pEu22104f22m8KkX               The Secret of Us
# 137  spotify:track:0b0Dz0Gi86SVdBxYeiQcCP                 Short n' Sweet
# 329  spotify:track:3WOhcATHxK2SLNeP5W3v1v  Guess featuring Billie Eilish
# 312  spotify:track:6CTnIURom7GvzLqXuFHrXA       Girl, You Know It's True
#
#      listen_count
# 51             53
# 396            42
# 137            19
# 329            17
# 312            13

# %% [markdown]
# ## 7. Generate Playlists

# %%
# Create playlists for each cluster
playlists = generate_cluster_playlists(clustered_df, song_data_scored, top_songs, top_n=30)

# Show playlist for cluster 0
print("Playlist for cluster 0:")
playlists[0].head()
# Out:
# Playlist for cluster 0:
#                    track                 artist  \
# 0            Sweet Dream  Sarah and the Sundays
# 1      She Calls Me Back             Noah Kahan
# 2                 Casual          Chappell Roan
# 3  Somebody Come Through          Wasia Project
# 4                 Beanie                Chezile
#
#                                      album  \
# 0             So You're Mad About the Cups
# 1                             Stick Season
# 2  The Rise and Fall of a Midwest Princess
# 3                                  Isotope
# 4                                   Beanie
#
#                                     uri  popularity_score
# 0  spotify:track:6DdJ2TjyiVcgjpYjrjyZBJ               NaN
# 1  spotify:track:1LvU6IFqQnXOIwJyBDb2io               NaN
# 2  spotify:track:3WSOUb3U7tqURbBSgZTrZX               NaN
# 3  spotify:track:4Sz61x2L4mYmtw47NBrzfC               NaN
# 4  spotify:track:5e0b9LgOfi3aJSKXFcOWRe               NaN
